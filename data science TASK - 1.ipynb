# %% [markdown]
# # LetsGrowMorw Data Science Internship August 2022

# %% [markdown]
# # Task 1 - Iris Flower Classification ML Project

# %% [markdown]
# # Name - Shashi Anand

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import scikitplot as skplt

# %%
columns=['Sepal length','Sepal width','Patel length', 'Patel width','Species']
df=pd.read_csv('iris.data', names=columns)

# %%
df.head()                         # it takes first five values of the dataset
# Out:
#    Sepal length  Sepal width  Patel length  Patel width      Species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.tail()                        # it takes last five values of the dataset
# Out:
#      Sepal length  Sepal width  Patel length  Patel width         Species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
df.isnull()                 #it finds that how many values are null
# Out:
#      Sepal length  Sepal width  Patel length  Patel width  Species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Sepal length    0
# Sepal width     0
# Patel length    0
# Patel width     0
# Species         0
# dtype: int64

# %%
df.describe()                # it describes the statistical values
# Out:
#        Sepal length  Sepal width  Patel length  Patel width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.columns          # decribes the columna in the dataset
# Out:
# Index(['Sepal length', 'Sepal width', 'Patel length', 'Patel width',
#        'Species'],
#       dtype='object')

# %%
df.nunique()        # it finds the unique values in the dataset
# Out:
# Sepal length    35
# Sepal width     23
# Patel length    43
# Patel width     22
# Species          3
# dtype: int64

# %%
df.max()             #it finds maximum vaules
# Out:
# Sepal length               7.9
# Sepal width                4.4
# Patel length               6.9
# Patel width                2.5
# Species         Iris-virginica
# dtype: object

# %%
df.min()           # it finds minimum values
# Out:
# Sepal length            4.3
# Sepal width             2.0
# Patel length            1.0
# Patel width             0.1
# Species         Iris-setosa
# dtype: object

# %% [markdown]
# # DATA VISUALIZATION

# %%
# create  a figure ands axis
fig, ax= plt.subplots()

#scatter the sepal length and sepal width
ax.scatter(df['Sepal length'], df['Sepal width'])

#set a title and labels
ax.set_title('Iris dataset')
ax.set_xlabel('Sepal length')
ax.set_ylabel('Sepal width')
plt.show()

# %%
# Regression plot
sns.regplot(x='Patel width', y='Patel length', data=df)
plt.show()

# %%
#Violinplot

sns.violinplot(x="Species", y="Sepal length", data=df, inner='quartile')
plt.show()
sns.violinplot(x="Species", y="Sepal width", data=df, inner='quartile')
plt.show()
sns.violinplot(x="Species", y="Patel length", data=df, inner='quartile')
plt.show()
sns.violinplot(x="Species", y="Patel width", data=df, inner='quartile')
plt.show()

# %%
#visualization of whole dataset

sns.pairplot(df,hue='Species')

# %%
# heat map graph

plt.figure(figsize=(7,5))
sns.heatmap(df.corr(), annot=True, cmap='cubehelix_r')
plt.show()

# %% [markdown]
# # Trainig the model

# %%
X=df.iloc[:,:4]
Y=df.iloc[:,4]
print(X)
# Out:
#      Sepal length  Sepal width  Patel length  Patel width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
print(Y)
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %% [markdown]
# # TRAIN AND TEST THE MODEL

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=0)
print(X_train.shape)
print(X_test.shape)
# Out:
# (105, 4)
# (45, 4)

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
lR=LogisticRegression()
lR.fit(X_train,Y_train)
print("Accuracy:", lR.score(X_test, Y_test))
# Out:
# Accuracy: 0.9777777777777777

# %% [markdown]
# # SUPPORT VECTOR MACHINE

# %%
from sklearn import svm
model=svm.SVC()
model.fit(X_train,Y_train)
print("Accuracy:", model.score(X_test, Y_test))
# Out:
# Accuracy: 0.9777777777777777

# %% [markdown]
# # THANK YOU
